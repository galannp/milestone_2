# %%
import pandas as pd
import numpy as np
import re

# %%
dict_ = {'key 1': 'value 1', 
         'key 2': 'value 2', 
         'key 3': 'Mitt Romney: “thu, apr 26, 2012”',
        'key 4': 'random text tesing ',
        'key 5': 'Mitt Romney: “thu, apr 26, 2012”',
         'key 7': ' > ',
         'key 8': '< ',
         'key 9': '< ad',
         'key 10': ' ad >',
         'key 11': ' <href= >',
        'key 6': 'But the call was already disconnected. Sanchez has been placed on administrative duty, meaning he has been moved out of the dispatch center. An internal investigation has been launched into the incident and officials say they\'re taking the allegation very seriously. MORE LOCAL NEWS & nbsp & nbsp & nbsp & nbsp & nbsp & nbsp & nbsp & nbsp & nbsp & nbsp & nbsp & nbsp & nbsp  a href = >'}
df = pd.DataFrame(dict_.items(),columns=['test','bla'])

# %%
df
# Out:
#       test                                                bla
# 0    key 1                                            value 1
# 1    key 2                                            value 2
# 2    key 3                   Mitt Romney: “thu, apr 26, 2012”
# 3    key 4                                random text tesing
# 4    key 5                   Mitt Romney: “thu, apr 26, 2012”
# 5    key 7                                                 >
# 6    key 8                                                 <
# 7    key 9                                               < ad
# 8   key 10                                               ad >
# 9   key 11                                           <href= >
# 10   key 6  But the call was already disconnected. Sanchez...

# %%
df
# Out:
#       test                                                bla
# 0    key 1                                            value 1
# 1    key 2                                            value 2
# 2    key 3                   Mitt Romney: “thu, apr 26, 2012”
# 3    key 4                                random text tesing
# 4    key 5                   Mitt Romney: “thu, apr 26, 2012”
# 5    key 7                                                 >
# 6    key 8                                                 <
# 7    key 9                                               < ad
# 8   key 10                                               ad >
# 9   key 11                                           <href= >
# 10   key 6  But the call was already disconnected. Sanchez...

# %%
# detects if a row has a (or has a part of) a html tag in quote and then removes it
df[~df['bla'].str.contains('|'.join(('.*?>', '<.*?', '<.*?>')))]
# Out:
#     test                               bla
# 0  key 1                           value 1
# 1  key 2                           value 2
# 2  key 3  Mitt Romney: “thu, apr 26, 2012”
# 3  key 4               random text tesing
# 4  key 5  Mitt Romney: “thu, apr 26, 2012”

# %%
df
# Out:
#       test                                                bla
# 0    key 1                                            value 1
# 1    key 2                                            value 2
# 2    key 3                   Mitt Romney: “thu, apr 26, 2012”
# 3    key 4                                random text tesing
# 4    key 5                   Mitt Romney: “thu, apr 26, 2012”
# 5    key 7                                                 >
# 6    key 8                                                 <
# 7    key 9                                               < ad
# 8   key 10                                               ad >
# 9   key 11                                           <href= >
# 10   key 6  But the call was already disconnected. Sanchez...

# %%
#df[~df['bla'].str.contains(' (0[1-9] | [1-2][0-9] | 3[0-1]), (19|20)\d{2}', regex=True)]
df[~df['bla'].str.contains(' \d{2}, (19|20)\d{2}', regex=True)]
# Out:
# <ipython-input-71-9f375e5610f6>:2: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   df[~df['bla'].str.contains(' \d{2}, (19|20)\d{2}', regex=True)]
#       test                                                bla
# 0    key 1                                            value 1
# 1    key 2                                            value 2
# 3    key 4                                random text tesing
# 5    key 7                                                 >
# 6    key 8                                                 <
# 7    key 9                                               < ad
# 8   key 10                                               ad >
# 9   key 11                                           <href= >
# 10   key 6  But the call was already disconnected. Sanchez...

# %%
df['bla'].apply(lambda x : check_if_date(x))
# Out:
# 0      True
# 1      True
# 2      True
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# Name: bla, dtype: bool

# %%
# initializing string
test_str = 'Mitt Romney: “thu, apr 26, 2012”'
# Out:
#   File "C:\Users\Younes\AppData\Local\Temp/ipykernel_11060/949915675.py", line 3
#     thu, apr 26, 2012
#              ^
# SyntaxError: invalid syntax

# %%
check_if_date('m6061779999610')
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11060/438128635.py in <module>
# ----> 1 check_if_date('m6061779999610')
#
# ~\AppData\Local\Temp/ipykernel_11060/2531691885.py in check_if_date(string)
#       3 def check_if_date(string):
#       4     try:
# ----> 5         parse(string, fuzzy = True)
#       6         return True
#       7     except ValueError:
#
# C:\ProgramData\Anaconda3\envs\ada\lib\site-packages\dateutil\parser\_parser.py in parse(timestr, parserinfo, **kwargs)
#    1366         return parser(parserinfo).parse(timestr, **kwargs)
#    1367     else:
# -> 1368         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1369
#    1370
#
# C:\ProgramData\Anaconda3\envs\ada\lib\site-packages\dateutil\parser\_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     647
#     648         try:
# --> 649             ret = self._build_naive(res, default)
#     650         except ValueError as e:
#     651             six.raise_from(ParserError(str(e) + ": %s", timestr), e)
#
# C:\ProgramData\Anaconda3\envs\ada\lib\site-packages\dateutil\parser\_parser.py in _build_naive(self, res, default)
#    1233                 repl['day'] = monthrange(cyear, cmonth)[1]
#    1234
# -> 1235         naive = default.replace(**repl)
#    1236
#    1237         if res.weekday is not None and not res.day:
#
# OverflowError: Python int too large to convert to C long

# %%
is_date(test_str, fuzzy=True)
# Out:
# True

# %%
df[df['bla'].str.contains(r'\d')]
# Out:
#     test                               bla
# 0  key 1                           value 1
# 1  key 2                           value 2
# 2  key 3  Mitt Romney: “thu, apr 26, 2012”
# 4  key 5  Mitt Romney: “thu, apr 26, 2012”
